# %% [markdown]
# ## 聚类理论基础

# %% [markdown]
# ### 聚类任务-整体介绍聚类算法

# %% [markdown]
# ### 性能度量-衡量聚类的有效性

# %% [markdown]
# ### 距离计算

# %% [markdown]
# ## 聚类方法

# %% [markdown]
# ### 原型聚类

# %% [markdown]
# 1. kmeans
# 2. 学习向量化
# 3. 高斯混合聚类

# %% [markdown]
# ### 密度聚类

# %% [markdown]
# DBSCAN

# %% [markdown]
# ### 层次聚类

# %% [markdown]
# AGNES
