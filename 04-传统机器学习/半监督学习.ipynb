# %% [markdown]
# ## 什么是半监督学习
#
# ### 定义
#
# 不依赖外界交互，自动利用未标记的样本。
#
# ### 方法
#
# 相似样本具有相似输出。
#
# ### 分类
#
# 纯半监督学习和直推学习。
#
#
#
# ## 半监督的学习的方法
#
# ### 生成式方法
#
# - 高斯混合模型
#
# ### 半监督SVM
#
# ### 图半监督学习
#
#
# ### 基于分歧的方法
#
#
# ### 半监督聚类
